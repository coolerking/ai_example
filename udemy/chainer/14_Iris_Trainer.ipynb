# %% [markdown]
# # Trainer による訓練

# %%
# coding: UTF-8

import chainer
from chainer import Variable, Chain, optimizers
import chainer.links as L
import chainer.functions as F

# Trainer用
from chainer.datasets import tuple_dataset
from chainer import training, iterators
from chainer.training import extensions

import numpy as np
from sklearn import datasets # Scikit Learn にIris dataset が含まれている

# %%
# Iris データの読み込み
iris_data = datasets.load_iris()

# %%
x = iris_data.data.astype(np.float32)
t = iris_data.target
n = t.size

# %%
# 教師データの下処理
t_matrix = np.zeros(3 * n).reshape(n, 3).astype(np.float32)
for i in range(n):
    t_matrix[i, t[i]] = 1.0

# %%
# 訓練用データとテスト用データ 半分が訓練用データで残りがテスト用データ
indexes = np.arange(n)
indexes_train = indexes[indexes%2 != 0]
indexes_test = indexes[indexes%2 == 0]

x_train = x[indexes_train, :] # 訓練用 入力
t_train = t_matrix[indexes_train, :] # 訓練用 正解
x_test = x[indexes_test, :] # テスト用 入力
t_test = t[indexes_test] # テスト用 正解

# tuple_dataset を使う
train = tuple_dataset.TupleDataset(x_train, t_train)
#x_train_v = Variable(x_train)
#t_train_v = Variable(t_train)
x_test_v = Variable(x_test)

# %%
# Chain の記述
class IrisChain(Chain):
    def __init__(self):
        super(IrisChain, self).__init__(
            l1 = L.Linear(4, 6),
            l2 = L.Linear(6, 6),
            l3 = L.Linear(6, 3),
        )
    
    # __call_追加
    def __call__(self, x, t):
        return F.mean_squared_error(self.predict(x), t)
        
    def predict(self, x):
        h1 = F.sigmoid(self.l1(x))
        h2 = F.sigmoid(self.l2(h1))
        h3 = self.l3(h2)
        return h3

# %%
# モデルとOptimizerの設定
model = IrisChain()
optimizer = optimizers.Adam()
optimizer.setup(model)

# %%
# 学習

#for i in range(10000):
#    
#    model.cleargrads()
#    y_train_v = model.predict(x_train_v)
#    
#    # 損失関数による誤差の計算、この場合は平均2乗誤差
#    loss = F.mean_squared_error(y_train_v, t_train_v)
#    loss.backward()
#    
#    # Optimizer による重みの更新
#    optimizer.update()

# Trainer を使う
train_iter = iterators.SerialIterator(train, 30) # 1回の学習30個だけ使う
updater = training.StandardUpdater(train_iter, optimizer)
trainer = training.Trainer(updater, (5000, 'epoch'))
trainer.extend(extensions.ProgressBar())
trainer.run()
# Out:
#      total [..................................................]  0.80%
# this epoch [..................................................]  0.00%
#        100 iter, 40 epoch / 5000 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  1.60%
# this epoch [..................................................]  0.00%
#        200 iter, 80 epoch / 5000 epochs
#     252.55 iters/sec. Estimated time to finish: 0:00:48.703121.
#      total [#.................................................]  2.40%
# this epoch [..................................................]  0.00%
#        300 iter, 120 epoch / 5000 epochs
#     249.09 iters/sec. Estimated time to finish: 0:00:48.978097.
#      total [#.................................................]  3.20%
# this epoch [..................................................]  0.00%
#        400 iter, 160 epoch / 5000 epochs
#     256.22 iters/sec. Estimated time to finish: 0:00:47.225622.
#      total [##................................................]  4.00%
# this epoch [..................................................]  0.00%
#        500 iter, 200 epoch / 5000 epochs
#     260.78 iters/sec. Estimated time to finish: 0:00:46.015399.
#      total [##................................................]  4.80%
# this epoch [..................................................]  0.00%
#        600 iter, 240 epoch / 5000 epochs
#     263.88 iters/sec. Estimated time to finish: 0:00:45.096494.
#      total [##................................................]  5.60%
# this epoch [..................................................]  0.00%
#        700 iter, 280 epoch / 5000 epochs
#     267.17 iters/sec. Estimated time to finish: 0:00:44.166917.
#      total [###...............................................]  6.40%
# this epoch [..................................................]  0.00%
#        800 iter, 320 epoch / 5000 epochs
#     266.69 iters/sec. Estimated time to finish: 0:00:43.870613.
#      total [###...............................................]  7.20%
# this epoch [..................................................]  0.00%
#        900 iter, 360 epoch / 5000 epochs
#     266.96 iters/sec. Estimated time to finish: 0:00:43.452158.
#      total [####..............................................]  8.00%
# this epoch [..................................................]  0.00%
#       1000 iter, 400 epoch / 5000 epochs
#     267.49 iters/sec. Estimated time to finish: 0:00:42.992924.
#      total [####..............................................]  8.80%
# this epoch [..................................................]  0.00%
#       1100 iter, 440 epoch / 5000 epochs
#     268.27 iters/sec. Estimated time to finish: 0:00:42.494951.
#      total [####..............................................]  9.60%
# this epoch [..................................................]  0.00%
#       1200 iter, 480 epoch / 5000 epochs
#      267.6 iters/sec. Estimated time to finish: 0:00:42.226960.
#      total [#####.............................................] 10.40%
# this epoch [..................................................]  0.00%
#       1300 iter, 520 epoch / 5000 epochs
#     267.17 iters/sec. Estimated time to finish: 0:00:41.921140.
#      total [#####.............................................] 11.20%
# this epoch [..................................................]  0.00%
#       1400 iter, 560 epoch / 5000 epochs
#     272.96 iters/sec. Estimated time to finish: 0:00:40.664625.
#      total [######............................................] 12.00%
# this epoch [..................................................]  0.00%
#       1500 iter, 600 epoch / 5000 epochs
#     278.14 iters/sec. Estimated time to finish: 0:00:39.548902.
#      total [######............................................] 12.80%
# this epoch [..................................................]  0.00%
#       1600 iter, 640 epoch / 5000 epochs
#     283.26 iters/sec. Estimated time to finish: 0:00:38.480417.
#      total [######............................................] 13.60%
# this epoch [..................................................]  0.00%
#       1700 iter, 680 epoch / 5000 epochs
#     288.16 iters/sec. Estimated time to finish: 0:00:37.479002.
#      total [#######...........................................] 14.40%
# this epoch [..................................................]  0.00%
#       1800 iter, 720 epoch / 5000 epochs
#     292.03 iters/sec. Estimated time to finish: 0:00:36.640689.
#      total [#######...........................................] 15.20%
# this epoch [..................................................]  0.00%
#       1900 iter, 760 epoch / 5000 epochs
#     295.16 iters/sec. Estimated time to finish: 0:00:35.912743.
#      total [########..........................................] 16.00%
# this epoch [..................................................]  0.00%
#       2000 iter, 800 epoch / 5000 epochs
#     296.03 iters/sec. Estimated time to finish: 0:00:35.469875.
#      total [########..........................................] 16.80%
# this epoch [..................................................]  0.00%
#       2100 iter, 840 epoch / 5000 epochs
#     298.49 iters/sec. Estimated time to finish: 0:00:34.841716.
#      total [########..........................................] 17.60%
# this epoch [..................................................]  0.00%
#       2200 iter, 880 epoch / 5000 epochs
#     299.73 iters/sec. Estimated time to finish: 0:00:34.364231.
#      total [#########.........................................] 18.40%
# this epoch [..................................................]  0.00%
#       2300 iter, 920 epoch / 5000 epochs
#     300.66 iters/sec. Estimated time to finish: 0:00:33.925516.
#      total [#########.........................................] 19.20%
# this epoch [..................................................]  0.00%
#       2400 iter, 960 epoch / 5000 epochs
#     301.79 iters/sec. Estimated time to finish: 0:00:33.467174.
#      total [##########........................................] 20.00%
# this epoch [..................................................]  0.00%
#       2500 iter, 1000 epoch / 5000 epochs
#     302.91 iters/sec. Estimated time to finish: 0:00:33.013366.
#      total [##########........................................] 20.80%
# this epoch [..................................................]  0.00%
#       2600 iter, 1040 epoch / 5000 epochs
#      304.5 iters/sec. Estimated time to finish: 0:00:32.512309.
#      total [##########........................................] 21.60%
# this epoch [..................................................]  0.00%
#       2700 iter, 1080 epoch / 5000 epochs
#      305.3 iters/sec. Estimated time to finish: 0:00:32.099328.
#      total [###########.......................................] 22.40%
# this epoch [..................................................]  0.00%
#       2800 iter, 1120 epoch / 5000 epochs
#     306.22 iters/sec. Estimated time to finish: 0:00:31.676313.
#      total [###########.......................................] 23.20%
# this epoch [..................................................]  0.00%
#       2900 iter, 1160 epoch / 5000 epochs
#      308.1 iters/sec. Estimated time to finish: 0:00:31.159170.
#      total [############......................................] 24.00%
# this epoch [..................................................]  0.00%
#       3000 iter, 1200 epoch / 5000 epochs
#     310.29 iters/sec. Estimated time to finish: 0:00:30.616422.
#      total [############......................................] 24.80%
# this epoch [..................................................]  0.00%
#       3100 iter, 1240 epoch / 5000 epochs
#     311.98 iters/sec. Estimated time to finish: 0:00:30.130253.
#      total [############......................................] 25.60%
# this epoch [..................................................]  0.00%
#       3200 iter, 1280 epoch / 5000 epochs
#     312.47 iters/sec. Estimated time to finish: 0:00:29.763024.
#      total [#############.....................................] 26.40%
# this epoch [..................................................]  0.00%
#       3300 iter, 1320 epoch / 5000 epochs
#     313.42 iters/sec. Estimated time to finish: 0:00:29.353689.
#      total [#############.....................................] 27.20%
# this epoch [..................................................]  0.00%
#       3400 iter, 1360 epoch / 5000 epochs
#     313.51 iters/sec. Estimated time to finish: 0:00:29.026097.
#      total [##############....................................] 28.00%
# this epoch [..................................................]  0.00%
#       3500 iter, 1400 epoch / 5000 epochs
#     314.73 iters/sec. Estimated time to finish: 0:00:28.595964.
#      total [##############....................................] 28.80%
# this epoch [..................................................]  0.00%
#       3600 iter, 1440 epoch / 5000 epochs
#     315.23 iters/sec. Estimated time to finish: 0:00:28.233063.
#      total [##############....................................] 29.60%
# this epoch [..................................................]  0.00%
#       3700 iter, 1480 epoch / 5000 epochs
#     315.99 iters/sec. Estimated time to finish: 0:00:27.849215.
#      total [###############...................................] 30.40%
# this epoch [..................................................]  0.00%
#       3800 iter, 1520 epoch / 5000 epochs
#     316.54 iters/sec. Estimated time to finish: 0:00:27.484549.
#      total [###############...................................] 31.20%
# this epoch [..................................................]  0.00%
#       3900 iter, 1560 epoch / 5000 epochs
#     316.57 iters/sec. Estimated time to finish: 0:00:27.166493.
#      total [################..................................] 32.00%
# this epoch [..................................................]  0.00%
#       4000 iter, 1600 epoch / 5000 epochs
#      316.8 iters/sec. Estimated time to finish: 0:00:26.831163.
#      total [################..................................] 32.80%
# this epoch [..................................................]  0.00%
#       4100 iter, 1640 epoch / 5000 epochs
#     317.06 iters/sec. Estimated time to finish: 0:00:26.493051.
#      total [################..................................] 33.60%
# this epoch [..................................................]  0.00%
#       4200 iter, 1680 epoch / 5000 epochs
#      318.4 iters/sec. Estimated time to finish: 0:00:26.067490.
#      total [#################.................................] 34.40%
# this epoch [..................................................]  0.00%
#       4300 iter, 1720 epoch / 5000 epochs
#     318.72 iters/sec. Estimated time to finish: 0:00:25.727856.
#      total [#################.................................] 35.20%
# this epoch [..................................................]  0.00%
#       4400 iter, 1760 epoch / 5000 epochs
#     319.95 iters/sec. Estimated time to finish: 0:00:25.316561.
#      total [##################................................] 36.00%
# this epoch [..................................................]  0.00%
#       4500 iter, 1800 epoch / 5000 epochs
#     319.43 iters/sec. Estimated time to finish: 0:00:25.044768.
#      total [##################................................] 36.80%
# this epoch [..................................................]  0.00%
#       4600 iter, 1840 epoch / 5000 epochs
#     320.16 iters/sec. Estimated time to finish: 0:00:24.675376.
#      total [##################................................] 37.60%
# this epoch [..................................................]  0.00%
#       4700 iter, 1880 epoch / 5000 epochs
#     321.31 iters/sec. Estimated time to finish: 0:00:24.275920.
#      total [###################...............................] 38.40%
# this epoch [..................................................]  0.00%
#       4800 iter, 1920 epoch / 5000 epochs
#     322.39 iters/sec. Estimated time to finish: 0:00:23.883994.
#      total [###################...............................] 39.20%
# this epoch [..................................................]  0.00%
#       4900 iter, 1960 epoch / 5000 epochs
#      323.2 iters/sec. Estimated time to finish: 0:00:23.514898.
#      total [####################..............................] 40.00%
# this epoch [..................................................]  0.00%
#       5000 iter, 2000 epoch / 5000 epochs
#     324.11 iters/sec. Estimated time to finish: 0:00:23.140543.
#      total [####################..............................] 40.80%
# this epoch [..................................................]  0.00%
#       5100 iter, 2040 epoch / 5000 epochs
#     324.98 iters/sec. Estimated time to finish: 0:00:22.770483.
#      total [####################..............................] 41.60%
# this epoch [..................................................]  0.00%
#       5200 iter, 2080 epoch / 5000 epochs
#     325.85 iters/sec. Estimated time to finish: 0:00:22.403034.
#      total [#####################.............................] 42.40%
# this epoch [..................................................]  0.00%
#       5300 iter, 2120 epoch / 5000 epochs
#     326.65 iters/sec. Estimated time to finish: 0:00:22.042257.
#      total [#####################.............................] 43.20%
# this epoch [..................................................]  0.00%
#       5400 iter, 2160 epoch / 5000 epochs
#     325.55 iters/sec. Estimated time to finish: 0:00:21.809555.
#      total [######################............................] 44.00%
# this epoch [..................................................]  0.00%
#       5500 iter, 2200 epoch / 5000 epochs
#     324.05 iters/sec. Estimated time to finish: 0:00:21.601914.
#      total [######################............................] 44.80%
# this epoch [..................................................]  0.00%
#       5600 iter, 2240 epoch / 5000 epochs
#     322.31 iters/sec. Estimated time to finish: 0:00:21.407932.
#      total [######################............................] 45.60%
# this epoch [..................................................]  0.00%
#       5700 iter, 2280 epoch / 5000 epochs
#     321.04 iters/sec. Estimated time to finish: 0:00:21.181096.
#      total [#######################...........................] 46.40%
# this epoch [..................................................]  0.00%
#       5800 iter, 2320 epoch / 5000 epochs
#     319.92 iters/sec. Estimated time to finish: 0:00:20.943046.
#      total [#######################...........................] 47.20%
# this epoch [..................................................]  0.00%
#       5900 iter, 2360 epoch / 5000 epochs
#     318.94 iters/sec. Estimated time to finish: 0:00:20.693482.
#      total [########################..........................] 48.00%
# this epoch [..................................................]  0.00%
#       6000 iter, 2400 epoch / 5000 epochs
#     317.89 iters/sec. Estimated time to finish: 0:00:20.447616.
#      total [########################..........................] 48.80%
# this epoch [..................................................]  0.00%
#       6100 iter, 2440 epoch / 5000 epochs
#     316.97 iters/sec. Estimated time to finish: 0:00:20.191047.
#      total [########################..........................] 49.60%
# this epoch [..................................................]  0.00%
#       6200 iter, 2480 epoch / 5000 epochs
#     316.14 iters/sec. Estimated time to finish: 0:00:19.927696.
#      total [#########################.........................] 50.40%
# this epoch [..................................................]  0.00%
#       6300 iter, 2520 epoch / 5000 epochs
#     315.65 iters/sec. Estimated time to finish: 0:00:19.642036.
#      total [#########################.........................] 51.20%
# this epoch [..................................................]  0.00%
#       6400 iter, 2560 epoch / 5000 epochs
#      315.2 iters/sec. Estimated time to finish: 0:00:19.352493.
#      total [##########################........................] 52.00%
# this epoch [..................................................]  0.00%
#       6500 iter, 2600 epoch / 5000 epochs
#     314.37 iters/sec. Estimated time to finish: 0:00:19.085591.
#      total [##########################........................] 52.80%
# this epoch [..................................................]  0.00%
#       6600 iter, 2640 epoch / 5000 epochs
#     314.24 iters/sec. Estimated time to finish: 0:00:18.775553.
#      total [##########################........................] 53.60%
# this epoch [..................................................]  0.00%
#       6700 iter, 2680 epoch / 5000 epochs
#     314.84 iters/sec. Estimated time to finish: 0:00:18.421945.
#      total [###########################.......................] 54.40%
# this epoch [..................................................]  0.00%
#       6800 iter, 2720 epoch / 5000 epochs
#     315.52 iters/sec. Estimated time to finish: 0:00:18.065492.
#      total [###########################.......................] 55.20%
# this epoch [..................................................]  0.00%
#       6900 iter, 2760 epoch / 5000 epochs
#     316.22 iters/sec. Estimated time to finish: 0:00:17.709053.
#      total [############################......................] 56.00%
# this epoch [..................................................]  0.00%
#       7000 iter, 2800 epoch / 5000 epochs
#     316.89 iters/sec. Estimated time to finish: 0:00:17.355946.
#      total [############################......................] 56.80%
# this epoch [..................................................]  0.00%
#       7100 iter, 2840 epoch / 5000 epochs
#     317.52 iters/sec. Estimated time to finish: 0:00:17.006756.
#      total [############################......................] 57.60%
# this epoch [..................................................]  0.00%
#       7200 iter, 2880 epoch / 5000 epochs
#     317.98 iters/sec. Estimated time to finish: 0:00:16.667953.
#      total [#############################.....................] 58.40%
# this epoch [..................................................]  0.00%
#       7300 iter, 2920 epoch / 5000 epochs
#     318.64 iters/sec. Estimated time to finish: 0:00:16.319146.
#      total [#############################.....................] 59.20%
# this epoch [..................................................]  0.00%
#       7400 iter, 2960 epoch / 5000 epochs
#     319.27 iters/sec. Estimated time to finish: 0:00:15.973978.
#      total [##############################....................] 60.00%
# this epoch [..................................................]  0.00%
#       7500 iter, 3000 epoch / 5000 epochs
#        320 iters/sec. Estimated time to finish: 0:00:15.624789.
#      total [##############################....................] 60.80%
# this epoch [..................................................]  0.00%
#       7600 iter, 3040 epoch / 5000 epochs
#     320.68 iters/sec. Estimated time to finish: 0:00:15.279939.
#      total [##############################....................] 61.60%
# this epoch [..................................................]  0.00%
#       7700 iter, 3080 epoch / 5000 epochs
#     321.41 iters/sec. Estimated time to finish: 0:00:14.934085.
#      total [###############################...................] 62.40%
# this epoch [..................................................]  0.00%
#       7800 iter, 3120 epoch / 5000 epochs
#     321.82 iters/sec. Estimated time to finish: 0:00:14.604552.
#      total [###############################...................] 63.20%
# this epoch [..................................................]  0.00%
#       7900 iter, 3160 epoch / 5000 epochs
#     320.68 iters/sec. Estimated time to finish: 0:00:14.344668.
#      total [################################..................] 64.00%
# this epoch [..................................................]  0.00%
#       8000 iter, 3200 epoch / 5000 epochs
#     319.99 iters/sec. Estimated time to finish: 0:00:14.063087.
#      total [################################..................] 64.80%
# this epoch [..................................................]  0.00%
#       8100 iter, 3240 epoch / 5000 epochs
#     320.47 iters/sec. Estimated time to finish: 0:00:13.729927.
#      total [################################..................] 65.60%
# this epoch [..................................................]  0.00%
#       8200 iter, 3280 epoch / 5000 epochs
#     321.05 iters/sec. Estimated time to finish: 0:00:13.393426.
#      total [#################################.................] 66.40%
# this epoch [..................................................]  0.00%
#       8300 iter, 3320 epoch / 5000 epochs
#     321.63 iters/sec. Estimated time to finish: 0:00:13.058645.
#      total [#################################.................] 67.20%
# this epoch [..................................................]  0.00%
#       8400 iter, 3360 epoch / 5000 epochs
#     322.26 iters/sec. Estimated time to finish: 0:00:12.722559.
#      total [##################################................] 68.00%
# this epoch [..................................................]  0.00%
#       8500 iter, 3400 epoch / 5000 epochs
#     322.85 iters/sec. Estimated time to finish: 0:00:12.389713.
#      total [##################################................] 68.80%
# this epoch [..................................................]  0.00%
#       8600 iter, 3440 epoch / 5000 epochs
#     323.42 iters/sec. Estimated time to finish: 0:00:12.058512.
#      total [##################################................] 69.60%
# this epoch [..................................................]  0.00%
#       8700 iter, 3480 epoch / 5000 epochs
#     324.01 iters/sec. Estimated time to finish: 0:00:11.728013.
#      total [###################################...............] 70.40%
# this epoch [..................................................]  0.00%
#       8800 iter, 3520 epoch / 5000 epochs
#     324.56 iters/sec. Estimated time to finish: 0:00:11.399963.
#      total [###################################...............] 71.20%
# this epoch [..................................................]  0.00%
#       8900 iter, 3560 epoch / 5000 epochs
#     325.09 iters/sec. Estimated time to finish: 0:00:11.073802.
#      total [####################################..............] 72.00%
# this epoch [..................................................]  0.00%
#       9000 iter, 3600 epoch / 5000 epochs
#     325.54 iters/sec. Estimated time to finish: 0:00:10.751397.
#      total [####################################..............] 72.80%
# this epoch [..................................................]  0.00%
#       9100 iter, 3640 epoch / 5000 epochs
#        326 iters/sec. Estimated time to finish: 0:00:10.429401.
#      total [####################################..............] 73.60%
# this epoch [..................................................]  0.00%
#       9200 iter, 3680 epoch / 5000 epochs
#     326.45 iters/sec. Estimated time to finish: 0:00:10.108593.
#      total [#####################################.............] 74.40%
# this epoch [..................................................]  0.00%
#       9300 iter, 3720 epoch / 5000 epochs
#     326.95 iters/sec. Estimated time to finish: 0:00:09.787543.
#      total [#####################################.............] 75.20%
# this epoch [..................................................]  0.00%
#       9400 iter, 3760 epoch / 5000 epochs
#     327.37 iters/sec. Estimated time to finish: 0:00:09.469386.
#      total [######################################............] 76.00%
# this epoch [..................................................]  0.00%
#       9500 iter, 3800 epoch / 5000 epochs
#     327.78 iters/sec. Estimated time to finish: 0:00:09.152595.
#      total [######################################............] 76.80%
# this epoch [..................................................]  0.00%
#       9600 iter, 3840 epoch / 5000 epochs
#     328.15 iters/sec. Estimated time to finish: 0:00:08.837400.
#      total [######################################............] 77.60%
# this epoch [..................................................]  0.00%
#       9700 iter, 3880 epoch / 5000 epochs
#     328.56 iters/sec. Estimated time to finish: 0:00:08.521939.
#      total [#######################################...........] 78.40%
# this epoch [..................................................]  0.00%
#       9800 iter, 3920 epoch / 5000 epochs
#     328.99 iters/sec. Estimated time to finish: 0:00:08.206901.
#      total [#######################################...........] 79.20%
# this epoch [..................................................]  0.00%
#       9900 iter, 3960 epoch / 5000 epochs
#     329.47 iters/sec. Estimated time to finish: 0:00:07.891537.
#      total [########################################..........] 80.00%
# this epoch [..................................................]  0.00%
#      10000 iter, 4000 epoch / 5000 epochs
#     329.92 iters/sec. Estimated time to finish: 0:00:07.577525.
#      total [########################################..........] 80.80%
# this epoch [..................................................]  0.00%
#      10100 iter, 4040 epoch / 5000 epochs
#     330.27 iters/sec. Estimated time to finish: 0:00:07.266713.
#      total [########################################..........] 81.60%
# this epoch [..................................................]  0.00%
#      10200 iter, 4080 epoch / 5000 epochs
#     331.63 iters/sec. Estimated time to finish: 0:00:06.935416.
#      total [#########################################.........] 82.40%
# this epoch [..................................................]  0.00%
#      10300 iter, 4120 epoch / 5000 epochs
#     333.23 iters/sec. Estimated time to finish: 0:00:06.601980.
#      total [#########################################.........] 83.20%
# this epoch [..................................................]  0.00%
#      10400 iter, 4160 epoch / 5000 epochs
#      334.4 iters/sec. Estimated time to finish: 0:00:06.279842.
#      total [##########################################........] 84.00%
# this epoch [..................................................]  0.00%
#      10500 iter, 4200 epoch / 5000 epochs
#     335.63 iters/sec. Estimated time to finish: 0:00:05.959004.
#      total [##########################################........] 84.80%
# this epoch [..................................................]  0.00%
#      10600 iter, 4240 epoch / 5000 epochs
#     336.77 iters/sec. Estimated time to finish: 0:00:05.641866.
#      total [##########################################........] 85.60%
# this epoch [..................................................]  0.00%
#      10700 iter, 4280 epoch / 5000 epochs
#     337.79 iters/sec. Estimated time to finish: 0:00:05.328727.
#      total [###########################################.......] 86.40%
# this epoch [..................................................]  0.00%
#      10800 iter, 4320 epoch / 5000 epochs
#     338.52 iters/sec. Estimated time to finish: 0:00:05.021808.
#      total [###########################################.......] 87.20%
# this epoch [..................................................]  0.00%
#      10900 iter, 4360 epoch / 5000 epochs
#     338.48 iters/sec. Estimated time to finish: 0:00:04.727047.
#      total [############################################......] 88.00%
# this epoch [..................................................]  0.00%
#      11000 iter, 4400 epoch / 5000 epochs
#      338.4 iters/sec. Estimated time to finish: 0:00:04.432657.
#      total [############################################......] 88.80%
# this epoch [..................................................]  0.00%
#      11100 iter, 4440 epoch / 5000 epochs
#     338.45 iters/sec. Estimated time to finish: 0:00:04.136446.
#      total [############################################......] 89.60%
# this epoch [..................................................]  0.00%
#      11200 iter, 4480 epoch / 5000 epochs
#     338.66 iters/sec. Estimated time to finish: 0:00:03.838646.
#      total [#############################################.....] 90.40%
# this epoch [..................................................]  0.00%
#      11300 iter, 4520 epoch / 5000 epochs
#     338.82 iters/sec. Estimated time to finish: 0:00:03.541686.
#      total [#############################################.....] 91.20%
# this epoch [..................................................]  0.00%
#      11400 iter, 4560 epoch / 5000 epochs
#     337.68 iters/sec. Estimated time to finish: 0:00:03.257544.
#      total [##############################################....] 92.00%
# this epoch [..................................................]  0.00%
#      11500 iter, 4600 epoch / 5000 epochs
#     336.52 iters/sec. Estimated time to finish: 0:00:02.971603.
#      total [##############################################....] 92.80%
# this epoch [..................................................]  0.00%
#      11600 iter, 4640 epoch / 5000 epochs
#     335.04 iters/sec. Estimated time to finish: 0:00:02.686231.
#      total [##############################################....] 93.60%
# this epoch [..................................................]  0.00%
#      11700 iter, 4680 epoch / 5000 epochs
#     333.89 iters/sec. Estimated time to finish: 0:00:02.396000.
#      total [###############################################...] 94.40%
# this epoch [..................................................]  0.00%
#      11800 iter, 4720 epoch / 5000 epochs
#     332.85 iters/sec. Estimated time to finish: 0:00:02.103080.
#      total [###############################################...] 95.20%
# this epoch [..................................................]  0.00%
#      11900 iter, 4760 epoch / 5000 epochs
#     331.77 iters/sec. Estimated time to finish: 0:00:01.808459.
#      total [################################################..] 96.00%
# this epoch [..................................................]  0.00%
#      12000 iter, 4800 epoch / 5000 epochs
#     331.32 iters/sec. Estimated time to finish: 0:00:01.509099.
#      total [################################################..] 96.80%
# this epoch [..................................................]  0.00%
#      12100 iter, 4840 epoch / 5000 epochs
#     331.59 iters/sec. Estimated time to finish: 0:00:01.206319.
#      total [################################################..] 97.60%
# this epoch [..................................................]  0.00%
#      12200 iter, 4880 epoch / 5000 epochs
#     332.05 iters/sec. Estimated time to finish: 0:00:00.903480.
#      total [#################################################.] 98.40%
# this epoch [..................................................]  0.00%
#      12300 iter, 4920 epoch / 5000 epochs
#     332.67 iters/sec. Estimated time to finish: 0:00:00.601200.
#      total [#################################################.] 99.20%
# this epoch [..................................................]  0.00%
#      12400 iter, 4960 epoch / 5000 epochs
#     333.14 iters/sec. Estimated time to finish: 0:00:00.300170.
#      total [##################################################] 100.00%
# this epoch [..................................................]  0.00%
#      12500 iter, 5000 epoch / 5000 epochs
#     333.52 iters/sec. Estimated time to finish: 0:00:00.

# %%
# テスト
model.cleargrads()
y_test_v = model.predict(x_test_v)
y_test = y_test_v.data

# %%
# 正解数のカウント
correct = 0
rowCount = y_test.shape[0]
for i in range(rowCount):
    maxIndex = np.argmax(y_test[i, :])
    print(y_test[i, :], maxIndex)
    if maxIndex == t_test[i]:
        correct += 1

# 正解率
print("Correct:" , correct, "Total:", rowCount, "Accuracy:", correct / rowCount * 100, "%")
# Out:
# [  1.00500143e+00   1.93521380e-04  -1.67141855e-03] 0
# [ 1.00321567  0.00160341 -0.00115667] 0
# [  1.00537026e+00  -8.50707293e-05  -1.74383819e-03] 0
# [  1.00163150e+00   2.82947719e-03  -7.40632415e-04] 0
# [  9.96649981e-01   6.62927330e-03   2.18942761e-04] 0
# [  1.00566006e+00  -3.40059400e-04  -1.90351903e-03] 0
# [  1.00211370e+00   2.43870914e-03  -9.98780131e-04] 0
# [ 1.00778008 -0.00206526 -0.00264959] 0
# [  1.00629926e+00  -8.29413533e-04  -1.95114315e-03] 0
# [  1.00404572e+00   8.91014934e-04  -1.53450668e-03] 0
# [ 1.001562    0.00280778 -0.00100236] 0
# [ 1.00717258 -0.00148602 -0.00217883] 0
# [  9.94685054e-01   8.07599723e-03   4.04015183e-04] 0
# [  9.96546209e-01   6.63547218e-03   1.52900815e-04] 0
# [  1.00459647e+00   4.98339534e-04  -1.59429014e-03] 0
# [  9.97166932e-01   6.19344413e-03  -1.65551901e-05] 0
# [ 1.00720227 -0.00155742 -0.00238733] 0
# [  1.00194335e+00   2.56161392e-03  -9.92640853e-04] 0
# [  1.00618935e+00  -7.64325261e-04  -2.05485523e-03] 0
# [  1.00029159e+00   3.86826694e-03  -4.61623073e-04] 0
# [  1.00463903e+00   4.84392047e-04  -1.50011480e-03] 0
# [  1.00245059e+00   2.22162902e-03  -9.08240676e-04] 0
# [  9.96413171e-01   6.73346221e-03   1.23396516e-04] 0
# [  1.00499547e+00   2.02223659e-04  -1.67922676e-03] 0
# [  1.00553215e+00  -2.32890248e-04  -1.85124576e-03] 0
# [-0.00801362  1.04012048 -0.03795068] 1
# [ 0.01595448  0.94885844  0.07085021] 1
# [ 0.0055912   0.91363949  0.12006672] 1
# [ 0.01532666  0.92185682  0.10346897] 1
# [-0.0050009   1.03728926 -0.02395897] 1
# [-0.0186251   1.07072806 -0.05625926] 1
# [-0.01865919  1.06280851 -0.05960844] 1
# [ 0.00160323  1.00199246 -0.04274605] 1
# [ 0.00553791  0.8200196   0.21169741] 1
# [-0.02119453  0.53906137  0.48965847] 1
# [-0.00277354  0.41339034  0.59558719] 2
# [-0.00695814  0.42362136  0.58383727] 2
# [-0.01285018  1.04938424 -0.04700921] 1
# [ 0.0102195   0.94914192  0.07547213] 1
# [ 0.00460105  0.88835138  0.14642902] 1
# [-0.01422198  1.05702817 -0.05481927] 1
# [-0.01134689  1.04251456 -0.05317627] 1
# [ 0.00321488  0.75237155  0.27685124] 1
# [ 0.00691448  0.99166983  0.03023817] 1
# [-0.00736286  1.04565179 -0.04037212] 1
# [ -6.03690743e-04   9.53708112e-01   7.86861926e-02] 1
# [-0.01432313  1.05718374 -0.04869024] 1
# [-0.00658722  1.01553941  0.01735534] 1
# [-0.00689127  1.04267931 -0.02567415] 1
# [ 0.06545173  0.87474817 -0.00556551] 1
# [  1.02357566e-03  -6.33932203e-02   1.08910823e+00] 2
# [  2.76669860e-04  -3.40060741e-02   1.03919482e+00] 2
# [-0.00158645 -0.04805018  1.06480908] 2
# [-0.02856721  0.1195011   0.89170855] 2
# [-0.00479211 -0.02561615  1.0343318 ] 2
# [-0.00612606  0.18078016  0.81610227] 2
# [-0.00421698  0.00154048  0.99985397] 2
# [-0.00271143 -0.04861869  1.06771994] 2
# [ -7.48291612e-04   7.12552220e-02   9.16867256e-01] 2
# [ -2.69249082e-04  -6.48745894e-02   1.09948385e+00] 2
# [ -9.04157758e-04  -3.50573212e-02   1.04334927e+00] 2
# [ 0.00260328 -0.06091464  1.07822621] 2
# [  6.87882304e-04  -7.28707016e-03   1.00431907e+00] 2
# [-0.01475687  0.28753036  0.71967489] 2
# [-0.00409992 -0.03741348  1.05200911] 2
# [ 0.00307916 -0.03044282  1.02883959] 2
# [-0.00308384 -0.04559359  1.06366515] 2
# [-0.0015343   0.08924921  0.89348358] 2
# [ -8.79958272e-04  -4.44768518e-02   1.05772042e+00] 2
# [-0.01021172  0.33059001  0.67648828] 2
# [-0.00122644 -0.04642241  1.06129146] 2
# [-0.01286282  0.01805788  0.98937124] 2
# [  3.08856368e-04  -5.25059551e-02   1.06855083e+00] 2
# [-0.01614632  0.05380876  0.95197725] 2
# [-0.00351031 -0.01906107  1.02562153] 2
# Correct: 73 Total: 75 Accuracy: 97.33333333333334 %
